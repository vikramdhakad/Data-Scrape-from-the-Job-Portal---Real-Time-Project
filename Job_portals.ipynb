# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service

# %%
PATH = 'D:\Learnings\web_driver\chromedriver.exe'
driver = webdriver.Chrome(executable_path=PATH)
driver.get('https://barrie.hiringplatform.ca/list/Careers')
driver.maximize_window()
chrome_options = Options()
chrome_options.add_experimental_option("detach",True)
# Out:
# C:\Users\a\AppData\Local\Temp\ipykernel_16468\863316491.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path=PATH)

# %%
information = driver.find_elements(By.XPATH,'//h2[@class="vidcruiter-job-item-title"]')
title = []
for i in information:
    title.append(i.text)
types = driver.find_elements(By.CLASS_NAME,'vidcruiter-job-item-description-title')
job = []
for j in types:
    job.append(j.text)

# %%
data = pd.DataFrame()
data['Job title'] = title
data['Job Type'] = job

# %%
data
# Out:
#                                             Job title  \
# 0    Office Services Assistant - Corporate Facilities
# 1                                    Planner (Policy)
# 2                                       Fleet Analyst
# 3                                    Purchasing Agent
# 4   Manager of Financial Systems Support and Integ...
# 5        Manager of Facility Planning and Development
# 6                         Senior Youth Program Leader
# 7                                Youth Program Leader
# 8                                Lifeguard-Instructor
# 9            Recreation Client Service Representative
# 10                        Inclusion Support Assistant
# 11            Specialty Instructor (General Interest)
# 12                       Specialty Instructor (Dance)
# 13                      Instructor (General Interest)
# 14                                 Instructor (Dance)
# 15                       Assistant Instructor (Dance)
# ...

# %%
data.to_csv('data.csv')

# %%
driver.quit()
